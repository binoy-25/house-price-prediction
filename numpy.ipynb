# %%
pip install numpy

# %%
#1D array
import numpy as np
a=np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
#2D array
b=np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
#rangenp.arange(0,10,2)

# %%
#random
np.random.rand(3)
# Out:
# array([0.45314934, 0.60064148, 0.66861111])

# %%
a=np.array([1,4,9])
print(np.sqrt(a))
print(np.mean(a))
# Out:
# [1. 2. 3.]
# 4.666666666666667
